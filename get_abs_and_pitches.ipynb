# %%
## Contents of https://github.com/wellsoliver/py-gameday/blob/master/lib/__init__.py
## Only one small edit to BASE

from logging import getLogger, Handler
from urllib import urlopen
from warnings import simplefilter
from time import sleep

class NullHandler(Handler):
    def emit(self, record):
        pass

class CONSTANTS:

#     BASE = 'http://gd2.mlb.com/components/game/%LEAGUE%/'
    BASE = 'http://gd2.mlb.com/components/game/mlb/'
    FETCH_TRIES = 10

class Fetcher:
    @classmethod
    def fetch(self, url):
        for i in xrange(CONSTANTS.FETCH_TRIES):
            logger.debug('FETCH %s' % url)
            try:
                page = urlopen(url)
            except IOError, e:
                if i == CONSTANTS.FETCH_TRIES-1:
                    logger.error('ERROR %s (max tries %s exhausted)' % (url, CONSTANTS.FETCH_TRIES))
                sleep(1)
                continue

            if page.getcode() == 404:
                return None
            else:
                return page.read()
            break

logger = getLogger('gameday')
logger.addHandler(NullHandler())

# %%
# Edited contents of https://github.com/wellsoliver/py-gameday/blob/master/lib/atbats.py
# Only changed the save function and loaded pandas

from xml.dom import minidom
from bs4 import BeautifulSoup
from re import search
import pandas as pd # JKG Added this

class Pitch:
    def __init__(self, element, count, **kwargs):

        values = {}
        values['num'] = kwargs['num'] if 'num' in kwargs else None
        values['game_id'] = kwargs['game_id'] if 'game_id' in kwargs else None
        values['pitcher'] = kwargs['pitcher'] if 'pitcher' in kwargs else None
        values['batter'] = kwargs['batter'] if 'batter' in kwargs else None
        values['b'] = count['balls']
        values['s'] = count['strikes']
        
        # these change a lot :(
        # tired of taking them from the XML element
        # because maybe I don't have them in the schema
        FIELDS = ['des','id','type','x','y','on_1b','on_2b','on_3b','sv_id','start_speed',
            'end_speed','sz_top','sz_bot','pfx_x','pfx_z','px','pz','x0','y0','z0','vx0','vy0','vz0',
            'ax','ay','az','break_y','break_angle','break_length','pitch_type','type_confidence',
            'spin_dir','spin_rate','zone']

        for key in element.attributes.keys():
            if key in FIELDS:
                values[key] = element.attributes[key].value
        
        self.values = values

class AtBats(list):
    
    def save(self):

## This is the old save function that I overwrote
        
#         DB = store.Store()
#         for inning in self:
#             for atbat in inning:
#                 keys = [k for k in atbat.keys() if k != 'pitches']
#                 values = [None if atbat[k] == '' else atbat[k] for k in keys]
                
#                 print ','.join(keys)

#                 sql ='REPLACE INTO atbat (%s) VALUES(%s)' % (','.join(keys), ','.join(['%s'] * len(keys)))
#                 DB.query(sql, values)
#                 DB.save()

#                 for pitch in atbat['pitches']:
#                     pitch.save()

        AB_FIELDS = ['inning','num','p_throws','event','score','away_team_runs','start_tfs_zulu','des_es','start_tfs',
                  'pitcher','batter','half','game_id','b','b_height','home_team_runs','des','o','s','stand','event2']

        P_FIELDS = ['des','id','type','x','y','on_1b','on_2b','on_3b','sv_id','start_speed',
            'end_speed','sz_top','sz_bot','pfx_x','pfx_z','px','pz','x0','y0','z0','vx0','vy0','vz0',
            'ax','ay','az','break_y','break_angle','break_length','pitch_type','type_confidence',
            'spin_dir','spin_rate','zone']
        
        ab_values = dict((k,[]) for k in AB_FIELDS)
        p_values = dict((k,[]) for k in P_FIELDS)
                
        for inning in self:
            for atbat in inning:
                for key in ab_values.keys():
                    ab_values[key].append(atbat.get(key,None))
                
                for pitch in atbat['pitches']:
                    for key in p_values.keys():
                        p_values[key].append(pitch.values.get(key,None))

        return (pd.DataFrame(ab_values), pd.DataFrame(p_values))

        
    def __init__(self, gid, game_id):
        super(AtBats,self).__init__()

        year, month, day = gid.split('_')[1:4]
        url = '%syear_%s/month_%s/day_%s/%s/inning/' % (CONSTANTS.BASE, year, month, day, gid)        
        
        contents = Fetcher.fetch(url)
        if contents is None:
            return
        
        soup = BeautifulSoup(contents)

        inning_num = 1
        for inning_link in soup.findAll('a'):
            if search(r'inning_\d+\.xml', inning_link['href']):
                inning_url = '%s%s' % (url, inning_link['href'])
                doc = minidom.parseString(Fetcher.fetch(inning_url))
                
                inning = []
                
                for atbat in doc.getElementsByTagName('atbat'):
                    values = {}
                    half = atbat.parentNode.nodeName
                    for key in atbat.attributes.keys():
                        values[str(key)] = atbat.attributes[key].value

                    values['half'] = half
                    values['game_id'] = game_id
                    values['inning'] = inning_num
                    values['pitches'] = []
                    
                    balls = 0
                    strikes = 0
                    for pitch in atbat.getElementsByTagName('pitch'):
                        count = {'balls': balls, 'strikes': strikes}
                        kwargs = {'game_id': game_id,
                            'batter': values['batter'],
                            'pitcher': values['pitcher'],
                            'num': atbat.attributes['num'].value}
                        p = Pitch(pitch, count, **kwargs)
                        values['pitches'].append(p)

                        if pitch.attributes['type'].value == 'B':
                            balls = balls + 1
                        elif pitch.attributes['type'].value == 'S':
                            strikes = strikes + 1

                    inning.append(values)
                self.append(inning)
                inning_num += 1

# %%
import timeit
start = timeit.default_timer()

(atbats, pitches) = AtBats("gid_2014_10_14_slnmlb_sfnmlb_1", "Game_id").save()

stop = timeit.default_timer()
print stop - start 

atbats
# Out:
# 2.4638428688
#    away_team_runs  b b_height  batter  \
# 0            None  2      6-3  572761
# 1            None  2     5-11  445055
# 2            None  1      6-4  407812
# 3            None  1     5-11  453923
# 4            None  0      6-1  605412
# 5            None  1      6-1  457763
# 6            None  0     5-11  467055
# 7               0  0      6-4  452254
# 8            None  4      6-5  474832
# 9               0  0      6-3  448170
# 10           None  0      6-2  543063
# 11           None  0      6-1  488721
# 12           None  1      6-3  572761
# 13           None  0     5-11  445055
# 14           None  3      6-4  407812
# 15           None  4      6-2  543063
# 16           None  1     5-11  543633
# 17              4  0     5-11  453923
# 18           None  1      6-3  571431
# 19           None  1      6-2  425509
# 20           None  1      5-9  543939
# 21           None  1      6-3  150229
# 22           None  0      6-1  218596
# 23           None  3     5-11  453923
# 24           None  0      6-1  605412
# 25           None  2      6-1  545341
# 26           None  1      6-6  407793
# 27           None  3      6-3  572761
# 28           None  0      6-1  457763
# 29           None  1     5-11  467055
# ..            ... ..      ...     ...
# 46           None  0      6-1  457763
# 47           None  2     5-11  467055
# 48           None  0     5-11  445055
# 49           None  0      6-4  407812
# 50           None  1      6-3  571431
# 51              3  1      6-2  425509
# 52           None  2      5-9  543939
# 53           None  1      6-4  452254
# 54           None  1      6-5  474832
# 55           None  2      6-3  448170
# 56           None  1      6-3  150229
# 57              4  0      6-1  545341
# 58           None  0     5-10  518614
# 59           None  3      6-3  572761
# 60           None  0     5-11  445055
# 61           None  2      6-2  543063
# 62           None  2     5-11  543633
# 63           None  1     5-11  453923
# 64           None  1      6-4  407812
# 65           None  2      6-3  571431
# 66           None  0      6-2  425509
# 67           None  1      6-1  605412
# 68           None  1      6-1  457763
# 69           None  2     5-11  467055
# 70           None  0      5-9  543939
# 71           None  0      6-3  150229
# 72           None  0      6-1  545341
# 73           None  2      6-4  452254
# 74           None  0      6-5  474832
# 75           None  0      6-5  434604
#
#                                                   des  \
# 0             Matt Carpenter called out on strikes.
# 1   Jon Jay flies out to left fielder Travis Ishik...
# 2   Matt Holliday grounds out, second baseman Joe ...
# 3   Gregor Blanco pops out to shortstop Jhonny Per...
# 4    Joe Panik lines out to center fielder Jon Jay.
# 5   Buster Posey singles on a line drive to right ...
# 6   Pablo Sandoval singles on a line drive to left...
# 7   Hunter Pence doubles (1) on a line drive to ri...
# 8     John Lackey intentionally walks Brandon Belt.
# 9   Travis Ishikawa doubles (2) on a fly ball to c...
# 10  Brandon Crawford lines out to left fielder Mat...
# 11  Peter Bourjos grounds out, shortstop Brandon C...
# 12             Matt Carpenter strikes out swinging.
# 13  Jon Jay singles on a ground ball to center fie...
# 14  Matt Holliday grounds out, third baseman Pablo...
# 15                          Brandon Crawford walks.
# 16  Juan Perez singles on a line drive to left fie...
# 17  Gregor Blanco hits a sacrifice bunt.   Throwin...
# 18  Matt Adams grounds out, first baseman Brandon ...
# 19  Jhonny Peralta lines out to left fielder Travi...
# 20  Kolten Wong doubles (1) on a line drive to cen...
# 21        A.  J.   Pierzynski strikes out swinging.
# 22  Tim Hudson flies out to left fielder Matt Holl...
# 23             Gregor Blanco called out on strikes.
# 24  Joe Panik pops out to third baseman Matt Carpe...
# 25  Randal Grichuk grounds out, shortstop Brandon ...
# 26               John Lackey called out on strikes.
# 27  Matt Carpenter grounds out, second baseman Joe...
# 28  Buster Posey grounds out, shortstop Jhonny Per...
# 29                     Pablo Sandoval hit by pitch.
# ..                                                ...
# 46  Buster Posey grounds out, shortstop Jhonny Per...
# 47  Pablo Sandoval grounds out, shortstop Jhonny P...
# 48  Jon Jay singles on a line drive to left fielde...
# 49  Matt Holliday grounds out softly, third basema...
# 50  Matt Adams grounds out to first baseman Brando...
# 51  Jhonny Peralta singles on a ground ball to lef...
# 52  Kolten Wong flies out to center fielder Gregor...
# 53               Hunter Pence strikes out swinging.
# 54               Brandon Belt strikes out swinging.
# 55  Travis Ishikawa grounds out, second baseman Ko...
# 56  A.  J.   Pierzynski lines out to left fielder ...
# 57  Randal Grichuk homers (1) on a line drive to l...
# 58  Daniel Descalso grounds out, pitcher Jeremy Af...
# 59  Matt Carpenter singles on a line drive to righ...
# 60  Jon Jay grounds out, second baseman Joe Panik ...
# 61  Brandon Crawford flies out to left fielder Mat...
# 62  Juan Perez lines out to center fielder Jon Jay.
# 63             Gregor Blanco called out on strikes.
# 64  Matt Holliday grounds out, second baseman Joe ...
# 65  Matt Adams lines out to center fielder Gregor ...
# 66  Jhonny Peralta lines out to center fielder Gre...
# 67  Joe Panik lines out sharply to first baseman M...
# 68  Buster Posey flies out to right fielder Randal...
# 69  Pablo Sandoval lines out to third baseman Matt...
# 70  Kolten Wong lines out sharply to second basema...
# 71  A.  J.   Pierzynski grounds out to first basem...
# 72             Randal Grichuk strikes out swinging.
# 73  Hunter Pence grounds out softly, pitcher Seth ...
# 74  Brandon Belt lines out to center fielder Jon J...
# 75  Michael Morse grounds out to first baseman Mat...
#
#                                                des_es         event event2  \
# 0             Matt Carpenter se poncha sin tirarle.       Strikeout   None
# 1   Jon Jay batea elevado de out a jardinero izqui...        Flyout   None
# 2   Matt Holliday batea rodado de out, segunda bas...     Groundout   None
# 3   Gregor Blanco batea elevadito de out a campo c...       Pop Out   None
# 4   Joe Panik batea línea de out a jardinero centr...       Lineout   None
# 5   Buster Posey pega sencillo con línea a jardine...        Single   None
# 6   Pablo Sandoval pega sencillo con línea a jardi...        Single   None
# 7   Hunter Pence pega doble (1) con línea a jardin...        Double   None
# 8   John Lackey recibe base por bolas intencional ...   Intent Walk   None
# 9   Travis Ishikawa pega doble (2) con elevado a j...        Double   None
# 10  Brandon Crawford batea línea de out a jardiner...       Lineout   None
# 11  Peter Bourjos batea rodado de out, campo corto...     Groundout   None
# 12              Matt Carpenter se poncha tirándole.       Strikeout   None
# 13  Jon Jay pega sencillo con rodado a jardinero c...        Single   None
# 14  Matt Holliday batea rodado de out, tercera bas...     Groundout   None
# 15          Brandon Crawford recibe base por bolas.            Walk   None
# 16  Juan Perez pega sencillo con línea a jardinero...        Single   None
# 17  Gregor Blanco se sacrifica con toque.   Error ...      Sac Bunt  Error
# 18  Matt Adams batea rodado de out, primera base B...     Groundout   None
# 19  Jhonny Peralta batea línea de out a jardinero ...       Lineout   None
# 20  Kolten Wong pega doble (1) con línea a jardine...        Double   None
# 21         A.  J.   Pierzynski se poncha tirándole.       Strikeout   None
# 22  Tim Hudson batea elevado de out a jardinero iz...        Flyout   None
# 23             Gregor Blanco se poncha sin tirarle.       Strikeout   None
# 24  Joe Panik batea elevadito de out a tercera bas...       Pop Out   None
# 25  Randal Grichuk batea rodado de out, campo cort...     Groundout   None
# 26               John Lackey se poncha sin tirarle.       Strikeout   None
# 27  Matt Carpenter batea rodado de out, segunda ba...     Groundout   None
# 28  Buster Posey batea rodado de out, campo corto ...     Groundout   None
# 29         Pablo Sandoval golpeado por lanzamiento.    Hit By Pitch   None
# ..                                                ...           ...    ...
# 46  Buster Posey batea rodado de out, campo corto ...     Groundout   None
# 47  Pablo Sandoval batea rodado de out, campo cort...     Groundout   None
# 48  Jon Jay pega sencillo con línea a jardinero iz...        Single   None
# 49  Matt Holliday batea rodado de out suavemente a...     Groundout   None
# 50  Matt Adams batea rodado de out a primera base ...     Groundout   None
# 51  Jhonny Peralta pega sencillo con rodado a jard...        Single   None
# 52  Kolten Wong batea elevado de out a jardinero c...        Flyout   None
# 53                Hunter Pence se poncha tirándole.       Strikeout   None
# 54                Brandon Belt se poncha tirándole.       Strikeout   None
# 55  Travis Ishikawa batea rodado de out, segunda b...     Groundout   None
# 56  A.  J.   Pierzynski batea línea de out a jardi...       Lineout   None
# 57  Randal Grichuk batea jonrón (1) con línea por ...      Home Run   None
# 58  Daniel Descalso batea rodado de out, lanzador ...     Groundout   None
# 59  Matt Carpenter pega sencillo con línea a jardi...        Single   None
# 60  Jon Jay batea rodado de out, segunda base Joe ...     Groundout   None
# 61  Brandon Crawford batea elevado de out a jardin...        Flyout   None
# 62  Juan Perez batea línea de out a jardinero cent...       Lineout   None
# 63             Gregor Blanco se poncha sin tirarle.       Strikeout   None
# 64  Matt Holliday batea rodado de out, segunda bas...     Groundout   None
# 65  Matt Adams batea línea de out a jardinero cent...       Lineout   None
# 66  Jhonny Peralta batea línea de out a jardinero ...       Lineout   None
# 67  Joe Panik batea línea de out fuertemente a pri...       Lineout   None
# 68  Buster Posey batea elevado de out a jardinero ...        Flyout   None
# 69  Pablo Sandoval batea línea de out a tercera ba...       Lineout   None
# 70  Kolten Wong batea línea de out fuertemente a s...       Lineout   None
# 71  A.  J.   Pierzynski batea rodado de out a prim...     Groundout   None
# 72              Randal Grichuk se poncha tirándole.       Strikeout   None
# 73  Hunter Pence batea rodado de out suavemente, l...     Groundout   None
# 74  Brandon Belt batea línea de out a jardinero ce...       Lineout   None
# 75  Michael Morse batea rodado de out a primera ba...     Groundout   None
#
#     game_id    half          ...          inning  num  o p_throws pitcher  s  \
# 0   Game_id     top          ...               1    1  1        R  218596  3
# 1   Game_id     top          ...               1    2  2        R  218596  0
# 2   Game_id     top          ...               1    3  3        R  218596  1
# 3   Game_id  bottom          ...               1    4  1        R  407793  0
# 4   Game_id  bottom          ...               1    5  2        R  407793  1
# 5   Game_id  bottom          ...               1    6  2        R  407793  1
# 6   Game_id  bottom          ...               1    7  2        R  407793  2
# 7   Game_id  bottom          ...               1    8  2        R  407793  2
# 8   Game_id  bottom          ...               1    9  2        R  407793  0
# 9   Game_id  bottom          ...               1   10  2        R  407793  0
# 10  Game_id  bottom          ...               1   11  3        R  407793  1
# 11  Game_id     top          ...               2   70  1        L  425657  1
# 12  Game_id     top          ...               2   71  2        L  425657  3
# 13  Game_id     top          ...               2   72  2        L  425657  0
# 14  Game_id     top          ...               2   73  3        R  489265  2
# 15  Game_id  bottom          ...               2   74  0        L  329092  2
# 16  Game_id  bottom          ...               2   75  0        L  329092  2
# 17  Game_id  bottom          ...               2   76  0        L  329092  1
# 18  Game_id     top          ...               3   12  1        R  218596  1
# 19  Game_id     top          ...               3   13  2        R  218596  0
# 20  Game_id     top          ...               3   14  2        R  218596  2
# 21  Game_id     top          ...               3   15  3        R  218596  3
# 22  Game_id  bottom          ...               3   16  1        R  407793  2
# 23  Game_id  bottom          ...               3   17  2        R  407793  3
# 24  Game_id  bottom          ...               3   18  3        R  407793  1
# 25  Game_id     top          ...               4   19  1        R  218596  1
# 26  Game_id     top          ...               4   20  2        R  218596  3
# 27  Game_id     top          ...               4   21  3        R  218596  2
# 28  Game_id  bottom          ...               4   22  1        R  407793  2
# 29  Game_id  bottom          ...               4   23  1        R  407793  2
# ..      ...     ...          ...             ...  ... ..      ...     ... ..
# 46  Game_id  bottom          ...               6   40  2        R  407793  1
# 47  Game_id  bottom          ...               6   41  3        R  407793  1
# 48  Game_id     top          ...               7   42  0        R  218596  1
# 49  Game_id     top          ...               7   43  1        R  218596  1
# 50  Game_id     top          ...               7   44  2        R  218596  1
# 51  Game_id     top          ...               7   45  2        R  218596  0
# 52  Game_id     top          ...               7   46  3        R  218596  1
# 53  Game_id  bottom          ...               7   47  1        R  407793  3
# 54  Game_id  bottom          ...               7   48  2        R  407793  3
# 227  -11.681  27.941  -28.267        20.3          6.8    23.8
# 228  -13.842   27.03  -27.097        23.3          7.0    23.8
# 229  -14.438  26.935  -24.726        26.1          6.6    23.8
# 230    0.835  22.469  -32.638        -4.3          8.6    23.9
# 231    1.596  17.519   -30.94        -5.0          8.0    24.0
# 232  -15.153  28.962  -27.228        25.9          6.9    23.8
# 233  -15.477  30.617  -22.916        28.2          6.0    23.8
# 234  -13.861  36.088  -25.809        24.4          6.4    23.7
# 235    -4.39  19.763  -30.421         6.3         11.9    23.7
# 236  -13.657  27.644  -21.966        28.3          5.6    23.8
# 237  -18.495  27.509  -25.779        32.2          6.8    23.8
# 238   -5.575  15.793  -30.359         9.6         11.7    23.9
# 239   -2.925  14.767  -30.814         4.9         13.4    23.8
# 240  -15.672  36.721  -23.577        29.9          6.1    23.7
# 241  -16.991  32.496  -19.685        36.3          5.6    23.8
# 242    9.599  22.817  -42.008       -13.3         11.8    23.9
# 243  -11.987  30.766  -16.381        30.5          4.2    23.8
# 244  -14.808  32.665  -15.799        37.1          4.5    23.8
# 245    9.073   21.34  -46.302       -11.5         12.8    23.9
# 246  -11.912  30.045  -22.001        24.6          5.1    23.8
# 247   11.119  23.007  -45.881       -14.3         13.1    23.9
# 248   -9.244  30.867  -11.495        29.3          3.1    23.8
# 249   -0.466  22.151  -30.657         -.9          8.0    23.9
# 250    3.341  18.788  -32.347        -6.5          8.7    24.0
# 251   -9.567  24.546  -29.615        15.3          7.2    23.9
# 252  -12.551  29.851  -26.451        22.2          6.8    23.8
# 253   -5.329  22.329  -32.169         8.3          7.3    23.9
# 254    -6.65  23.152  -32.558        10.6          7.5    23.9
#
#                  des end_speed   id   on_1b  ...  type_confidence     vx0  \
# 0               Ball      81.7    3    None  ...             .811   1.301
# 1      Called Strike      82.6    4    None  ...             .000   4.013
# 2               Ball      73.7    5    None  ...             .901   3.404
# 3      Called Strike      82.0    6    None  ...             .000   2.938
# 4      Called Strike      78.4    7    None  ...             .905   1.674
# 5               Ball      82.7   11    None  ...             .000   2.331
# 6               Ball      83.2   12    None  ...             .000   3.266
# 7    In play, out(s)      82.9   13    None  ...             .000   5.198
# 8               Ball      83.5   17    None  ...             .996   8.403
# 9               Foul      83.6   18    None  ...             .000   1.626
# 10   In play, out(s)      83.8   19    None  ...             .000   6.455
# 11              Ball      83.6   24    None  ...             .777   5.257
# 12   In play, out(s)      84.2   25    None  ...             .892   5.838
# 13     Called Strike      82.6   29    None  ...             .903   4.761
# 14   In play, out(s)      84.5   30    None  ...             .907   5.211
# 15              Ball      85.4   34    None  ...             .904   2.279
# 16     Called Strike      85.1   35    None  ...             .903   7.191
# 17   In play, no out      85.2   36    None  ...             .903   5.309
# 18     Called Strike      84.9   40  457763  ...             .904   5.589
# 19              Foul      83.5   42  457763  ...             .903   7.553
# 20              Foul      85.6   43  457763  ...             .867   4.281
# 21   In play, no out      86.6   44  457763  ...             .865   4.337
# 22     Called Strike      85.9   49  467055  ...             .778   6.534
# 23              Foul      85.9   50  467055  ...             .892   5.432
# 24   In play, run(s)      86.9   51  467055  ...             .894   8.081
# 25              Ball      83.3   58    None  ...             .899  10.121
# 26              Ball      71.6   59    None  ...             .897   0.016
# 27      Ball In Dirt      72.9   60    None  ...             .895   4.902
# 28       Intent Ball      None   61    None  ...             None    None
# 29   In play, run(s)      84.2   65  474832  ...             .997   8.657
# ..               ...       ...  ...     ...  ...              ...     ...
# 225             Foul      85.1  429    None  ...             .917  -9.715
# 226  In play, out(s)      84.7  430    None  ...             .907  -8.242
# 227             Ball      83.8  437    None  ...             .000   5.829
# 228  In play, out(s)      83.3  438    None  ...             .000   9.587
# 229  Swinging Strike      83.0  442    None  ...             .000   9.777
# 230             Ball      78.4  443    None  ...             .903   9.882
# 231  Swinging Strike      79.3  444    None  ...             .902   8.378
# 232             Foul      85.6  445    None  ...             .000   6.782
# 233             Foul      84.5  446    None  ...             .000  12.547
# 234  In play, out(s)      83.7  447    None  ...             .000   7.789
# 235    Called Strike      63.3  451    None  ...             .901   5.929
# 236             Foul      85.2  452    None  ...             .000   7.518
# 237             Ball      86.4  453    None  ...             .000   8.132
# 238             Ball      65.2  454    None  ...             .903   3.006
# 239  In play, out(s)      60.5  455    None  ...             .903   2.382
# 240    Called Strike      86.4  462    None  ...             .920   5.171
# 241             Foul      87.1  463    None  ...             .922   5.118
# 242             Foul      76.8  464    None  ...             .900   2.111
# 243  In play, out(s)      88.6  465    None  ...             .482   6.764
# 244             Foul      87.0  469    None  ...             .758   7.596
# 245  In play, out(s)      77.0  470    None  ...             .904    2.33
# 246    Called Strike      87.8  474    None  ...             .908   7.332
# 247    Called Strike      76.2  475    None  ...             .904   3.183
# 248  Swinging Strike      87.6  476    None  ...             .973   8.763
# 249  Swinging Strike      78.6  483    None  ...             .766   5.982
# 250             Ball      78.8  484    None  ...             .888   3.683
# 251             Ball      84.1  485    None  ...             .000   7.071
# 252  In play, out(s)      82.6  486    None  ...             .000   7.055
# 253  In play, out(s)      84.3  490    None  ...             .000   3.979
# 254  In play, out(s)      84.3  496    None  ...             .000   3.175
#
#           vy0     vz0       x      x0       y    y0     z0  zone
# 0    -130.397   0.172  157.08  -1.675  121.75  50.0  5.208    11
# 1     -130.12  -4.293  125.32   -1.44  170.96  50.0  5.058    13
# 2    -117.462  -3.582  116.74  -1.219  179.60  50.0  5.098    13
# 3    -129.715  -2.348  134.76  -1.365  160.60  50.0  5.111    13
# 4    -124.486   -0.82  127.04  -1.698  157.15  50.0  5.038    13
# 5    -132.078   2.034  145.06  -1.488  122.61  50.0  5.217    11
# 6    -132.056  -4.148  127.90  -1.418  174.42  50.0   4.99    13
# 7    -131.299  -2.098  109.87  -1.289  157.15  50.0  5.027     7
# 8    -131.817  -6.492   48.07  -1.068  170.10  50.0  5.125    14
# 9    -132.282  -2.586  134.76  -1.296  162.33  50.0    5.1    13
# 10    -132.83  -3.601   89.27  -1.231  166.65  50.0  5.117    14
# 11    -131.11  -8.316  139.91  -2.644  166.65  50.0  6.227    13
# 12   -131.245  -7.315  113.30  -2.508  158.88  50.0  6.224     7
# 13   -132.606   -6.96  133.05  -2.565  144.20  50.0   6.22    11
# 14   -133.255  -6.094  112.45  -2.274  136.43  50.0   6.47     1
# 15   -133.697   -5.76  140.77  -2.118  139.02  50.0  6.284    11
# 16   -133.254   -7.63   84.12  -1.984  153.69  50.0  6.374     6
