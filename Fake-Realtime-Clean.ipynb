# %%
import pandas as pd
import numpy as np
from time import sleep
from datetime import date, timedelta
import twitter
import pickle

from scipy.stats import randint as sp_randint

from config import REDSHIFT_CONFIG
from src.features import *
from src.utils import *
from src.validation import *
from src.exploration import *
import src.realtime as rt

from sklearn.ensemble import RandomForestClassifier
from sklearn.grid_search import RandomizedSearchCV
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn import svm

pd.set_option('display.max_columns', 500)

# %%
# The four inputs
pitcher = 434378
pitcher_name = "Justin Verlander"
gid = "gid_2015_08_15_detmlb_houmlb_1"
tweeting = False

# Establish a connection to the redshift database
conn = create_rs_conn(config=REDSHIFT_CONFIG)
cur = conn.cursor()

# Connect to Twitter
with open('twitter_auth.pkl', 'rb') as pkl_file:
    twitter_auth_dict = pickle.load(pkl_file)

api = twitter.Api(consumer_key = twitter_auth_dict['consumer_key'],
                      consumer_secret = twitter_auth_dict['consumer_secret'],
                      access_token_key = twitter_auth_dict['access_token_key'],
                      access_token_secret = twitter_auth_dict['access_token_secret'])

# %%
#Get the historical pitcher info from redshift and store it
raw_query = """SELECT * FROM all_pitch_data \
WHERE game_id IN \
(SELECT DISTINCT game_id FROM all_pitch_data \
WHERE pitcher = %d)
""" % pitcher

sample_header, sample_rows = run_rs_query(cur, raw_query)
pitch_df = pd.DataFrame(sample_rows)
pitch_df.columns = sample_header

# %%
# Process GID information for realtime scraping
gid_components = gid.split("_")
game_date = "-".join(gid_components[1:4])
game_id = "/".join(gid_components[1:4]) + "/" + "-".join(gid_components[4:7])

teams = [x[0:3].upper() for x in gid_components[4:6]]
start_string = 'Tweeting predictions for ' + pitcher_name + '\'s pitches during today\'s game between ' + str(teams[0]) + ' and ' + str(teams[1]) + '.'

print start_string
if tweeting == True:
    api.PostUpdate(start_string)

# Set up object to make multiple predictions
pm = rt.Prediction_Machine(pitcher, pitch_df, game_date)

# Every three seconds, take a look at the server
# If there are new pitches, then load the whole game's information into the object
# Make predictions for all pitches, and report pitches that haven't been reported before

last_id = 0
preds_made = 0

for i in range(0,10000):
    print "Gettin' data!"

    # Peek at the server
    data = rt.AtBats(gid, game_id).save()

    new_data = data[data['id'].astype(int) > last_id]
    
    next_pitch = new_data.head(1)

    # No pitches since the last peek
    if next_pitch.empty:
        print "No new pitches yet"
        
    # There are new pitches
    else:
        new_id = int(next_pitch.id)

        if new_id > last_id:
            
            last_id = new_id
            
            # Make predictions on all pitches
            new_preds, new_targets = pm.get_new_pred(data)
                        
            if len(new_preds) > preds_made:
                
                # For each unreported pitch, report it
                for i in range(preds_made, len(new_preds)):
                    outcome = "right" if new_preds[i] == new_targets.values[i] else "wrong"
                    result_string = "Pitch " + str(i + 1) +": We'd have guessed " + \
                                    new_preds[i] + " and the answer was " + \
                                    new_targets.values[i] + " so we were " + outcome
                    
                    if tweeting == True:
                        api.PostUpdate(result_string)
                    print result_string
                    sleep(1)
                
                preds_made = len(new_preds)

    sleep(3) # No DOS attacks on MLB
# Out:
# Tweeting predictions for Justin Verlander's pitches during today's game between DET and HOU.
# Gettin' data!
# Pitch 1: We'd have guessed Fastball and the answer was Not_Fastball so we were wrong
# Pitch 2: We'd have guessed Not_Fastball and the answer was Fastball so we were wrong
# Pitch 3: We'd have guessed Fastball and the answer was Fastball so we were right
# Pitch 4: We'd have guessed Fastball and the answer was Fastball so we were right
# Pitch 5: We'd have guessed Fastball and the answer was Fastball so we were right
# Pitch 6: We'd have guessed Fastball and the answer was Fastball so we were right
# Pitch 7: We'd have guessed Fastball and the answer was Not_Fastball so we were wrong
# Pitch 8: We'd have guessed Fastball and the answer was Not_Fastball so we were wrong
# Pitch 9: We'd have guessed Not_Fastball and the answer was Not_Fastball so we were right
# Pitch 10: We'd have guessed Not_Fastball and the answer was Fastball so we were wrong
# Pitch 11: We'd have guessed Fastball and the answer was Fastball so we were right
# Pitch 12: We'd have guessed Fastball and the answer was Fastball so we were right
# Pitch 13: We'd have guessed Fastball and the answer was Not_Fastball so we were wrong
# Pitch 14: We'd have guessed Fastball and the answer was Not_Fastball so we were wrong
# Pitch 15: We'd have guessed Not_Fastball and the answer was Fastball so we were wrong
# Pitch 16: We'd have guessed Fastball and the answer was Fastball so we were right
# Pitch 17: We'd have guessed Not_Fastball and the answer was Fastball so we were wrong
# Pitch 18: We'd have guessed Not_Fastball and the answer was Not_Fastball so we were right
# Pitch 19: We'd have guessed Fastball and the answer was Not_Fastball so we were wrong
# Pitch 20: We'd have guessed Not_Fastball and the answer was Fastball so we were wrong
# Pitch 21: We'd have guessed Fastball and the answer was Fastball so we were right
# Pitch 22: We'd have guessed Not_Fastball and the answer was Fastball so we were wrong
# Pitch 23: We'd have guessed Fastball and the answer was Not_Fastball so we were wrong
# Pitch 24: We'd have guessed Not_Fastball and the answer was Not_Fastball so we were right
# Pitch 25: We'd have guessed Not_Fastball and the answer was Fastball so we were wrong
# Pitch 26: We'd have guessed Fastball and the answer was Fastball so we were right
# Pitch 27: We'd have guessed Fastball and the answer was Not_Fastball so we were wrong
# Pitch 28: We'd have guessed Not_Fastball and the answer was Not_Fastball so we were right
# Pitch 29: We'd have guessed Not_Fastball and the answer was Fastball so we were wrong
# Pitch 30: We'd have guessed Fastball and the answer was Fastball so we were right
# Pitch 31: We'd have guessed Not_Fastball and the answer was Fastball so we were wrong
# Pitch 32: We'd have guessed Fastball and the answer was Fastball so we were right
# Pitch 33: We'd have guessed Fastball and the answer was Not_Fastball so we were wrong
# Pitch 34: We'd have guessed Not_Fastball and the answer was Not_Fastball so we were right
# Pitch 35: We'd have guessed Not_Fastball and the answer was Fastball so we were wrong
# Pitch 36: We'd have guessed Not_Fastball and the answer was Not_Fastball so we were right
# Pitch 37: We'd have guessed Not_Fastball and the answer was Not_Fastball so we were right
# Pitch 38: We'd have guessed Fastball and the answer was Fastball so we were right
# Pitch 39: We'd have guessed Fastball and the answer was Not_Fastball so we were wrong
# Pitch 40: We'd have guessed Not_Fastball and the answer was Fastball so we were wrong
# Pitch 41: We'd have guessed Not_Fastball and the answer was Fastball so we were wrong
# Pitch 42: We'd have guessed Fastball and the answer was Fastball so we were right
# Pitch 43: We'd have guessed Fastball and the answer was Not_Fastball so we were wrong
# Pitch 44: We'd have guessed Not_Fastball and the answer was Not_Fastball so we were right
# Pitch 45: We'd have guessed Fastball and the answer was Fastball so we were right
# Pitch 46: We'd have guessed Fastball and the answer was Not_Fastball so we were wrong
# Pitch 47: We'd have guessed Not_Fastball and the answer was Fastball so we were wrong
# Pitch 48: We'd have guessed Fastball and the answer was Fastball so we were right
# Pitch 49: We'd have guessed Fastball and the answer was Not_Fastball so we were wrong
# Pitch 50: We'd have guessed Fastball and the answer was Not_Fastball so we were wrong
# Pitch 51: We'd have guessed Not_Fastball and the answer was Fastball so we were wrong
# Pitch 52: We'd have guessed Not_Fastball and the answer was Not_Fastball so we were right
# Pitch 53: We'd have guessed Fastball and the answer was Not_Fastball so we were wrong
# Pitch 54: We'd have guessed Not_Fastball and the answer was Fastball so we were wrong
# Pitch 55: We'd have guessed Fastball and the answer was Fastball so we were right
# Pitch 56: We'd have guessed Fastball and the answer was Not_Fastball so we were wrong
# Pitch 57: We'd have guessed Not_Fastball and the answer was Fastball so we were wrong
# Pitch 58: We'd have guessed Not_Fastball and the answer was Not_Fastball so we were right
# Pitch 59: We'd have guessed Not_Fastball and the answer was Not_Fastball so we were right
# Pitch 60: We'd have guessed Not_Fastball and the answer was Fastball so we were wrong
# Pitch 61: We'd have guessed Not_Fastball and the answer was Fastball so we were wrong
# Pitch 62: We'd have guessed Fastball and the answer was Not_Fastball so we were wrong
# Pitch 63: We'd have guessed Not_Fastball and the answer was Fastball so we were wrong
# Pitch 64: We'd have guessed Fastball and the answer was Fastball so we were right
# Pitch 65: We'd have guessed Not_Fastball and the answer was Fastball so we were wrong
# Pitch 66: We'd have guessed Not_Fastball and the answer was Fastball so we were wrong
# Pitch 67: We'd have guessed Fastball and the answer was Not_Fastball so we were wrong
# Pitch 68: We'd have guessed Not_Fastball and the answer was Not_Fastball so we were right
# Pitch 69: We'd have guessed Fastball and the answer was Not_Fastball so we were wrong
# Pitch 70: We'd have guessed Fastball and the answer was Fastball so we were right
# Pitch 71: We'd have guessed Not_Fastball and the answer was Not_Fastball so we were right
# Pitch 72: We'd have guessed Fastball and the answer was Fastball so we were right
# Pitch 73: We'd have guessed Fastball and the answer was Fastball so we were right
# Pitch 74: We'd have guessed Fastball and the answer was Not_Fastball so we were wrong
# Pitch 75: We'd have guessed Not_Fastball and the answer was Not_Fastball so we were right
# Pitch 76: We'd have guessed Fastball and the answer was Fastball so we were right
# Pitch 77: We'd have guessed Fastball and the answer was Fastball so we were right
# Pitch 78: We'd have guessed Fastball and the answer was Fastball so we were right
# Pitch 79: We'd have guessed Not_Fastball and the answer was Fastball so we were wrong
# Pitch 80: We'd have guessed Fastball and the answer was Fastball so we were right
# Pitch 81: We'd have guessed Fastball and the answer was Not_Fastball so we were wrong
# Pitch 82: We'd have guessed Fastball and the answer was Not_Fastball so we were wrong
# Pitch 83: We'd have guessed Not_Fastball and the answer was Fastball so we were wrong
# Pitch 84: We'd have guessed Fastball and the answer was Fastball so we were right
# Pitch 85: We'd have guessed Not_Fastball and the answer was Not_Fastball so we were right
# Pitch 86: We'd have guessed Fastball and the answer was Fastball so we were right
# Pitch 87: We'd have guessed Fastball and the answer was Fastball so we were right
# Pitch 88: We'd have guessed Fastball and the answer was Not_Fastball so we were wrong
# Pitch 89: We'd have guessed Not_Fastball and the answer was Fastball so we were wrong
# Pitch 90: We'd have guessed Not_Fastball and the answer was Fastball so we were wrong
# Pitch 91: We'd have guessed Fastball and the answer was Not_Fastball so we were wrong
# Pitch 92: We'd have guessed Fastball and the answer was Fastball so we were right
# Pitch 93: We'd have guessed Fastball and the answer was Fastball so we were right
# Pitch 94: We'd have guessed Fastball and the answer was Fastball so we were right
# Pitch 95: We'd have guessed Fastball and the answer was Fastball so we were right
# Pitch 96: We'd have guessed Not_Fastball and the answer was Not_Fastball so we were right
# Pitch 97: We'd have guessed Not_Fastball and the answer was Fastball so we were wrong
# Pitch 98: We'd have guessed Fastball and the answer was Fastball so we were right
# Pitch 99: We'd have guessed Fastball and the answer was Not_Fastball so we were wrong
# Pitch 100: We'd have guessed Fastball and the answer was Fastball so we were right
# Pitch 101: We'd have guessed Fastball and the answer was Not_Fastball so we were wrong
# Pitch 102: We'd have guessed Not_Fastball and the answer was Fastball so we were wrong
# Pitch 103: We'd have guessed Fastball and the answer was Not_Fastball so we were wrong
# Pitch 104: We'd have guessed Not_Fastball and the answer was Fastball so we were wrong
# Pitch 105: We'd have guessed Fastball and the answer was Fastball so we were right
# Pitch 106: We'd have guessed Fastball and the answer was Fastball so we were right
# Pitch 107: We'd have guessed Fastball and the answer was Fastball so we were right
# Gettin' data!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-41-27be9eaa766c> in <module>()
#      43
#      44             # Make predictions on all pitches
# ---> 45             new_preds, new_targets = pm.get_new_pred(data)
#      46
#      47             if len(new_preds) > preds_made:
#
# /Users/jasongoodman/Desktop/Coursework/Capstone/pitchPrediction/src/realtime.py in get_new_pred(self, new_pitches)
#     431                                                     cols_of_interest = self.cols_of_interest,
#     432                                                     date_subsetting = False, pitch_df = self.pitch_df,
# --> 433                                                     new_pitches= new_pitches)
#     434
#     435         #Create a split with training on everything before today's game
#
# /Users/jasongoodman/Desktop/Coursework/Capstone/pitchPrediction/src/realtime.py in get_pitcher_df_for_realtime(pitcher_id, binarize_pitches, cols_of_interest, date_subsetting, pitch_df, new_pitches)
#     251
#     252     #Make all the features encapsulated in the 'make_features' function
# --> 253     pitch_df = make_features(pitch_df)
#     254
#     255     #Remove pitches not containing metadata and tell the user how many were removed
#
# /Users/jasongoodman/Desktop/Coursework/Capstone/pitchPrediction/src/features.pyc in make_features(df)
#     292     df = append_ingame_pitch_count(df)
#     293     df = append_season_pitch_count(df)
# --> 294     df = append_previous_pitches_features(df)
#     295
#     296     #Zach's features
#
# /Users/jasongoodman/Desktop/Coursework/Capstone/pitchPrediction/src/features.pyc in append_previous_pitches_features(pitch_df)
#     230
#     231         # Calculate and append mean start speed of last three pitches
# --> 232         pitch_df['prev_pitches_mean_start_speed'] = pitch_grouped['start_speed'].apply(pd.rolling_mean, 3, min_periods=1).shift(1)
#     233         pitch_df['prev_pitches_mean_end_speed'] = pitch_grouped['end_speed'].apply(pd.rolling_mean, 3, min_periods=1).shift(1)
#     234         pitch_df['prev_pitches_mean_break_y'] = pitch_grouped['break_y'].apply(pd.rolling_mean, 3, min_periods=1).shift(1)
#
# /usr/local/lib/python2.7/site-packages/pandas/core/groupby.pyc in apply(self, func, *args, **kwargs)
#     669         # ignore SettingWithCopy here in case the user mutates
#     670         with option_context('mode.chained_assignment',None):
# --> 671             return self._python_apply_general(f)
#     672
#     673     def _python_apply_general(self, f):
#
# /usr/local/lib/python2.7/site-packages/pandas/core/groupby.pyc in _python_apply_general(self, f)
#     673     def _python_apply_general(self, f):
#     674         keys, values, mutated = self.grouper.apply(f, self._selected_obj,
# --> 675                                                    self.axis)
#     676
#     677         return self._wrap_applied_output(keys, values,
#
# /usr/local/lib/python2.7/site-packages/pandas/core/groupby.pyc in apply(self, f, data, axis)
#    1292             # group might be modified
#    1293             group_axes = _get_axes(group)
# -> 1294             res = f(group)
#    1295             if not _is_indexed_like(res, group_axes):
#    1296                 mutated = True
#
# /usr/local/lib/python2.7/site-packages/pandas/core/groupby.pyc in f(g)
#     665         @wraps(func)
#     666         def f(g):
# --> 667             return func(g, *args, **kwargs)
#     668
#     669         # ignore SettingWithCopy here in case the user mutates
#
# /usr/local/lib/python2.7/site-packages/pandas/stats/moments.pyc in f(arg, window, min_periods, freq, center, how, **kwargs)
#     642             return func(arg, window, minp, **kwds)
#     643         return _rolling_moment(arg, window, call_cython, min_periods, freq=freq,
# --> 644                                center=center, how=how, **kwargs)
#     645
#     646     return f
#
# /usr/local/lib/python2.7/site-packages/pandas/stats/moments.pyc in _rolling_moment(arg, window, func, minp, axis, freq, center, how, args, kwargs, **kwds)
#     382     arg = _conv_timerule(arg, freq, how)
#     383
# --> 384     return_hook, values = _process_data_structure(arg)
#     385
#     386     if values.size == 0:
#
# /usr/local/lib/python2.7/site-packages/pandas/stats/moments.pyc in _process_data_structure(arg, kill_inf)
#     433
#     434     if not issubclass(values.dtype.type, float):
# --> 435         values = values.astype(float)
#     436
#     437     if kill_inf:
#
# /usr/local/Cellar/python/2.7.9/Frameworks/Python.framework/Versions/2.7/lib/python2.7/decimal.pyc in __float__(self)
#    1586             s = "-nan" if self._sign else "nan"
#    1587         else:
# -> 1588             s = str(self)
#    1589         return float(s)
#    1590
#
# /usr/local/Cellar/python/2.7.9/Frameworks/Python.framework/Versions/2.7/lib/python2.7/decimal.pyc in __str__(self, eng, context)
#    1033             intpart = '0'
#    1034             fracpart = '.' + '0'*(-dotplace) + self._int
# -> 1035         elif dotplace >= len(self._int):
#    1036             intpart = self._int+'0'*(dotplace-len(self._int))
#    1037             fracpart = ''
#
# KeyboardInterrupt:
